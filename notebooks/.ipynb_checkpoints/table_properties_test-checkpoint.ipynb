# %%
import pandas as pd
import numpy as np
import json
from typing import List, Optional

# %%
class Table:
    def __init__(self, code: str, name: str, path: str, level1: List[str], aggregates: List[str], path2: Optional[str] = None):
        self.code = code
        self.name = name
        self.path = path
        self.level1 = level1
        self.aggregates = aggregates
        if path2 is not None:
            self.df = pd.merge(pd.read_csv(path), pd.read_csv(path2), on='SED_CODE_2021')
        else:
            self.df = pd.read_csv(path)
    
    def summary_stats(self) -> pd.DataFrame:
        # Calculate percentage of each category relative to the aggregate column
        for col in self.level1:
            self.df[f"{col}_by_{self.aggregates[0]}"] = self.df[col] / self.df[self.aggregates[0]] * 100
        return self.df

    def correlation(self, table: 'Table') -> float:
        # Merge and calculate correlation matrix of combined data
        merged_df = pd.merge(self.summary_stats(), table.summary_stats(), on='SED_CODE_2021')[self.level1 + table.level1]
        corr = merged_df.corr()
        off_diagonal = corr.values[~np.eye(corr.shape[0], dtype=bool)]
        table_corr = np.mean(np.abs(off_diagonal))
        return table_corr
    
    def melt(self) -> pd.DataFrame:
        # Melt the DataFrame to convert from wide to long format
        value_vars = self.level1
        melted_df = pd.melt(self.df, id_vars=['SED_CODE_2021'], value_vars=value_vars, var_name='l1_category', value_name='population')
        
        return melted_df
    
    def to_json(self) -> str:
        melted_df = self.melt()
        data = json.loads(melted_df.to_json(orient='records', indent=4))
        
        final_json = {
            "code": self.code,
            "name": self.name,
            "level1": self.level1,
            "data_level1": data
        }
        
        return json.dumps(final_json, indent=4)
    
    def __str__(self) -> str:
        s = f"Table name: {self.name}\nTable code: {self.code}\nDataset path: {self.path}\nLevel 1 statistics: {self.level1}\nAggregate columns: {self.aggregates}"
        return s

# %%
g04_level1 = ['Age_yr_45_49_P', 'Age_yr_50_54_P', 'Age_yr_55_59_P', 'Age_yr_60_64_P', 'Age_yr_65_69_P', 'Age_yr_70_74_P', 'Age_yr_75_79_P',
               'Age_yr_80_84_P', 'Age_yr_85_89_P', 'Age_yr_90_94_P', 'Age_yr_95_99_P', 'Age_yr_100_yr_over_P']
g04_aggregates = ['Tot_P']
g04 = Table(code='g04',
            name='Age by sex',
            path='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G04A_NSW_SED.csv',
            path2='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G04B_NSW_SED.csv',
            level1=g04_level1,
            aggregates=g04_aggregates)

g04.df.head()
# Out:
#   SED_CODE_2021  Age_yr_0_M  Age_yr_0_F  Age_yr_0_P  Age_yr_1_M  Age_yr_1_F  \
# 0      SED10001         493         480         968         469         506
# 1      SED10002         790         769        1557         870         737
# 2      SED10003         362         405         769         371         363
# 3      SED10004         524         497        1023         433         409
# 4      SED10005         706         688        1394         688         733
#
#    Age_yr_1_P  Age_yr_2_M  Age_yr_2_F  Age_yr_2_P  ...  Age_yr_90_94_P  \
# 0         979         534         488        1022  ...             669
# 1        1606         787         684        1473  ...             383
# 2         736         438         372         809  ...             791
# 3         842         446         443         888  ...             296
# 4        1420         737         732        1464  ...             617
#
#    Age_yr_95_99_M  Age_yr_95_99_F  Age_yr_95_99_P  Age_yr_100_yr_over_M  \
# 0              53             131             190                     4
# 1              38              80             125                     4
# 2              68             156             227                     5
# 3              24              67              86                     0
# 4              43             110             151                     8
#
#    Age_yr_100_yr_over_F  Age_yr_100_yr_over_P  Tot_M  Tot_F   Tot_P
# 0                    18                    20  41715  43275   84989
# 1                     8                    13  61755  56069  117822
# 2                    24                    24  39585  42816   82405
# 3                     6                     6  40216  43054   83273
# 4                    20                    28  47284  47384   94669
#
# [5 rows x 307 columns]

# %%
print(g04.to_json())
# Out:
# {
#     "code": "g04",
#     "name": "Age by sex",
#     "level1": [
#         "Age_yr_45_49_P",
#         "Age_yr_50_54_P",
#         "Age_yr_55_59_P",
#         "Age_yr_60_64_P",
#         "Age_yr_65_69_P",
#         "Age_yr_70_74_P",
#         "Age_yr_75_79_P",
#         "Age_yr_80_84_P",
#         "Age_yr_85_89_P",
#         "Age_yr_90_94_P",
#         "Age_yr_95_99_P",
#         "Age_yr_100_yr_over_P"
#     ],
#     "data_level1": [
#         {
#             "SED_CODE_2021": "SED10001",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4932
#         },
#         {
#             "SED_CODE_2021": "SED10002",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6328
#         },
#         {
#             "SED_CODE_2021": "SED10003",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5582
#         },
#         {
#             "SED_CODE_2021": "SED10004",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6296
#         },
#         {
#             "SED_CODE_2021": "SED10005",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5667
#         },
#         {
#             "SED_CODE_2021": "SED10006",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4124
#         },
#         {
#             "SED_CODE_2021": "SED10007",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4914
#         },
#         {
#             "SED_CODE_2021": "SED10008",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6293
#         },
#         {
#             "SED_CODE_2021": "SED10009",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4205
#         },
#         {
#             "SED_CODE_2021": "SED10010",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5517
#         },
#         {
#             "SED_CODE_2021": "SED10011",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5012
#         },
#         {
#             "SED_CODE_2021": "SED10012",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5450
#         },
#         {
#             "SED_CODE_2021": "SED10013",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 8613
#         },
#         {
#             "SED_CODE_2021": "SED10014",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5031
#         },
#         {
#             "SED_CODE_2021": "SED10015",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6468
#         },
#         {
#             "SED_CODE_2021": "SED10016",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 8026
#         },
#         {
#             "SED_CODE_2021": "SED10017",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5362
#         },
#         {
#             "SED_CODE_2021": "SED10018",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5003
#         },
#         {
#             "SED_CODE_2021": "SED10019",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4529
#         },
#         {
#             "SED_CODE_2021": "SED10020",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4889
#         },
#         {
#             "SED_CODE_2021": "SED10021",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5597
#         },
#         {
#             "SED_CODE_2021": "SED10022",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4206
#         },
#         {
#             "SED_CODE_2021": "SED10023",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5681
#         },
#         {
#             "SED_CODE_2021": "SED10024",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6443
#         },
#         {
#             "SED_CODE_2021": "SED10025",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5673
#         },
#         {
#             "SED_CODE_2021": "SED10026",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4675
#         },
#         {
#             "SED_CODE_2021": "SED10027",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5457
#         },
#         {
#             "SED_CODE_2021": "SED10028",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6146
#         },
#         {
#             "SED_CODE_2021": "SED10029",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5898
#         },
#         {
#             "SED_CODE_2021": "SED10030",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5030
#         },
#         {
#             "SED_CODE_2021": "SED10031",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5310
#         },
#         {
#             "SED_CODE_2021": "SED10032",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5810
#         },
#         {
#             "SED_CODE_2021": "SED10033",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5348
#         },
#         {
#             "SED_CODE_2021": "SED10034",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5599
#         },
#         {
#             "SED_CODE_2021": "SED10035",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6300
#         },
#         {
#             "SED_CODE_2021": "SED10036",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6167
#         },
#         {
#             "SED_CODE_2021": "SED10037",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6537
#         },
#         {
#             "SED_CODE_2021": "SED10038",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5677
#         },
#         {
#             "SED_CODE_2021": "SED10039",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4684
#         },
#         {
#             "SED_CODE_2021": "SED10040",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5469
#         },
#         {
#             "SED_CODE_2021": "SED10041",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6379
#         },
#         {
#             "SED_CODE_2021": "SED10042",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4783
#         },
#         {
#             "SED_CODE_2021": "SED10043",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5338
#         },
#         {
#             "SED_CODE_2021": "SED10044",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6270
#         },
#         {
#             "SED_CODE_2021": "SED10045",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4913
#         },
#         {
#             "SED_CODE_2021": "SED10046",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6167
#         },
#         {
#             "SED_CODE_2021": "SED10047",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 7163
#         },
#         {
#             "SED_CODE_2021": "SED10048",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6926
#         },
#         {
#             "SED_CODE_2021": "SED10049",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5539
#         },
#         {
#             "SED_CODE_2021": "SED10050",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6617
#         },
#         {
#             "SED_CODE_2021": "SED10051",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6282
#         },
#         {
#             "SED_CODE_2021": "SED10052",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5683
#         },
#         {
#             "SED_CODE_2021": "SED10053",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5911
#         },
#         {
#             "SED_CODE_2021": "SED10054",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5935
#         },
#         {
#             "SED_CODE_2021": "SED10055",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6031
#         },
#         {
#             "SED_CODE_2021": "SED10056",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5101
#         },
#         {
#             "SED_CODE_2021": "SED10057",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4043
#         },
#         {
#             "SED_CODE_2021": "SED10058",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4924
#         },
#         {
#             "SED_CODE_2021": "SED10059",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5212
#         },
#         {
#             "SED_CODE_2021": "SED10060",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5297
#         },
#         {
#             "SED_CODE_2021": "SED10061",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4542
#         },
#         {
#             "SED_CODE_2021": "SED10062",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5372
#         },
#         {
#             "SED_CODE_2021": "SED10063",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4862
#         },
#         {
#             "SED_CODE_2021": "SED10064",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4398
#         },
#         {
#             "SED_CODE_2021": "SED10065",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6520
#         },
#         {
#             "SED_CODE_2021": "SED10066",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5390
#         },
#         {
#             "SED_CODE_2021": "SED10067",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5480
#         },
#         {
#             "SED_CODE_2021": "SED10068",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4686
#         },
#         {
#             "SED_CODE_2021": "SED10069",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4635
#         },
#         {
#             "SED_CODE_2021": "SED10070",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5594
#         },
#         {
#             "SED_CODE_2021": "SED10071",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 8710
#         },
#         {
#             "SED_CODE_2021": "SED10072",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5751
#         },
#         {
#             "SED_CODE_2021": "SED10073",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5882
#         },
#         {
#             "SED_CODE_2021": "SED10074",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5658
#         },
#         {
#             "SED_CODE_2021": "SED10075",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5735
#         },
#         {
#             "SED_CODE_2021": "SED10076",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4139
#         },
#         {
#             "SED_CODE_2021": "SED10077",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5673
#         },
#         {
#             "SED_CODE_2021": "SED10078",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5600
#         },
#         {
#             "SED_CODE_2021": "SED10079",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4441
#         },
#         {
#             "SED_CODE_2021": "SED10080",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5679
#         },
#         {
#             "SED_CODE_2021": "SED10081",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4663
#         },
#         {
#             "SED_CODE_2021": "SED10082",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5135
#         },
#         {
#             "SED_CODE_2021": "SED10083",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4809
#         },
#         {
#             "SED_CODE_2021": "SED10084",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5105
#         },
#         {
#             "SED_CODE_2021": "SED10085",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5044
#         },
#         {
#             "SED_CODE_2021": "SED10086",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5394
#         },
#         {
#             "SED_CODE_2021": "SED10087",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4639
#         },
#         {
#             "SED_CODE_2021": "SED10088",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6495
#         },
#         {
#             "SED_CODE_2021": "SED10089",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5228
#         },
#         {
#             "SED_CODE_2021": "SED10090",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 6686
#         },
#         {
#             "SED_CODE_2021": "SED10091",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5474
#         },
#         {
#             "SED_CODE_2021": "SED10092",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 4958
#         },
#         {
#             "SED_CODE_2021": "SED10093",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 5190
#         },
#         {
#             "SED_CODE_2021": "SED19494",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 877
#         },
#         {
#             "SED_CODE_2021": "SED19797",
#             "l1_category": "Age_yr_45_49_P",
#             "population": 0
#         },
#         {
#             "SED_CODE_2021": "SED10001",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5262
#         },
#         {
#             "SED_CODE_2021": "SED10002",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6220
#         },
#         {
#             "SED_CODE_2021": "SED10003",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5517
#         },
#         {
#             "SED_CODE_2021": "SED10004",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5651
#         },
#         {
#             "SED_CODE_2021": "SED10005",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5323
#         },
#         {
#             "SED_CODE_2021": "SED10006",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4721
#         },
#         {
#             "SED_CODE_2021": "SED10007",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5229
#         },
#         {
#             "SED_CODE_2021": "SED10008",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5708
#         },
#         {
#             "SED_CODE_2021": "SED10009",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4907
#         },
#         {
#             "SED_CODE_2021": "SED10010",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5133
#         },
#         {
#             "SED_CODE_2021": "SED10011",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5049
#         },
#         {
#             "SED_CODE_2021": "SED10012",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5745
#         },
#         {
#             "SED_CODE_2021": "SED10013",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 7165
#         },
#         {
#             "SED_CODE_2021": "SED10014",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4562
#         },
#         {
#             "SED_CODE_2021": "SED10015",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6411
#         },
#         {
#             "SED_CODE_2021": "SED10016",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6932
#         },
#         {
#             "SED_CODE_2021": "SED10017",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5396
#         },
#         {
#             "SED_CODE_2021": "SED10018",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4884
#         },
#         {
#             "SED_CODE_2021": "SED10019",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4798
#         },
#         {
#             "SED_CODE_2021": "SED10020",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4933
#         },
#         {
#             "SED_CODE_2021": "SED10021",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5213
#         },
#         {
#             "SED_CODE_2021": "SED10022",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4451
#         },
#         {
#             "SED_CODE_2021": "SED10023",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5359
#         },
#         {
#             "SED_CODE_2021": "SED10024",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6239
#         },
#         {
#             "SED_CODE_2021": "SED10025",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5288
#         },
#         {
#             "SED_CODE_2021": "SED10026",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4985
#         },
#         {
#             "SED_CODE_2021": "SED10027",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5150
#         },
#         {
#             "SED_CODE_2021": "SED10028",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5643
#         },
#         {
#             "SED_CODE_2021": "SED10029",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6140
#         },
#         {
#             "SED_CODE_2021": "SED10030",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5151
#         },
#         {
#             "SED_CODE_2021": "SED10031",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5602
#         },
#         {
#             "SED_CODE_2021": "SED10032",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5268
#         },
#         {
#             "SED_CODE_2021": "SED10033",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5633
#         },
#         {
#             "SED_CODE_2021": "SED10034",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5242
#         },
#         {
#             "SED_CODE_2021": "SED10035",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5451
#         },
#         {
#             "SED_CODE_2021": "SED10036",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5722
#         },
#         {
#             "SED_CODE_2021": "SED10037",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6057
#         },
#         {
#             "SED_CODE_2021": "SED10038",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5218
#         },
#         {
#             "SED_CODE_2021": "SED10039",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4679
#         },
#         {
#             "SED_CODE_2021": "SED10040",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5318
#         },
#         {
#             "SED_CODE_2021": "SED10041",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6141
#         },
#         {
#             "SED_CODE_2021": "SED10042",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4886
#         },
#         {
#             "SED_CODE_2021": "SED10043",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5279
#         },
#         {
#             "SED_CODE_2021": "SED10044",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5780
#         },
#         {
#             "SED_CODE_2021": "SED10045",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5218
#         },
#         {
#             "SED_CODE_2021": "SED10046",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6010
#         },
#         {
#             "SED_CODE_2021": "SED10047",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6205
#         },
#         {
#             "SED_CODE_2021": "SED10048",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6087
#         },
#         {
#             "SED_CODE_2021": "SED10049",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5451
#         },
#         {
#             "SED_CODE_2021": "SED10050",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6142
#         },
#         {
#             "SED_CODE_2021": "SED10051",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5702
#         },
#         {
#             "SED_CODE_2021": "SED10052",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5170
#         },
#         {
#             "SED_CODE_2021": "SED10053",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6307
#         },
#         {
#             "SED_CODE_2021": "SED10054",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5800
#         },
#         {
#             "SED_CODE_2021": "SED10055",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5754
#         },
#         {
#             "SED_CODE_2021": "SED10056",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5457
#         },
#         {
#             "SED_CODE_2021": "SED10057",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4553
#         },
#         {
#             "SED_CODE_2021": "SED10058",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4977
#         },
#         {
#             "SED_CODE_2021": "SED10059",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4800
#         },
#         {
#             "SED_CODE_2021": "SED10060",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5115
#         },
#         {
#             "SED_CODE_2021": "SED10061",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4957
#         },
#         {
#             "SED_CODE_2021": "SED10062",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5228
#         },
#         {
#             "SED_CODE_2021": "SED10063",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4823
#         },
#         {
#             "SED_CODE_2021": "SED10064",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4867
#         },
#         {
#             "SED_CODE_2021": "SED10065",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5815
#         },
#         {
#             "SED_CODE_2021": "SED10066",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4968
#         },
#         {
#             "SED_CODE_2021": "SED10067",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5402
#         },
#         {
#             "SED_CODE_2021": "SED10068",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4937
#         },
#         {
#             "SED_CODE_2021": "SED10069",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4737
#         },
#         {
#             "SED_CODE_2021": "SED10070",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5130
#         },
#         {
#             "SED_CODE_2021": "SED10071",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6613
#         },
#         {
#             "SED_CODE_2021": "SED10072",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5574
#         },
#         {
#             "SED_CODE_2021": "SED10073",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5413
#         },
#         {
#             "SED_CODE_2021": "SED10074",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4969
#         },
#         {
#             "SED_CODE_2021": "SED10075",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5447
#         },
#         {
#             "SED_CODE_2021": "SED10076",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4475
#         },
#         {
#             "SED_CODE_2021": "SED10077",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5460
#         },
#         {
#             "SED_CODE_2021": "SED10078",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5189
#         },
#         {
#             "SED_CODE_2021": "SED10079",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4890
#         },
#         {
#             "SED_CODE_2021": "SED10080",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5144
#         },
#         {
#             "SED_CODE_2021": "SED10081",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4765
#         },
#         {
#             "SED_CODE_2021": "SED10082",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5172
#         },
#         {
#             "SED_CODE_2021": "SED10083",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4684
#         },
#         {
#             "SED_CODE_2021": "SED10084",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4854
#         },
#         {
#             "SED_CODE_2021": "SED10085",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5293
#         },
#         {
#             "SED_CODE_2021": "SED10086",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4976
#         },
#         {
#             "SED_CODE_2021": "SED10087",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4708
#         },
#         {
#             "SED_CODE_2021": "SED10088",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 6245
#         },
#         {
#             "SED_CODE_2021": "SED10089",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 4848
#         },
#         {
#             "SED_CODE_2021": "SED10090",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5807
#         },
#         {
#             "SED_CODE_2021": "SED10091",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5485
#         },
#         {
#             "SED_CODE_2021": "SED10092",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5002
#         },
#         {
#             "SED_CODE_2021": "SED10093",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 5180
#         },
#         {
#             "SED_CODE_2021": "SED19494",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 801
#         },
#         {
#             "SED_CODE_2021": "SED19797",
#             "l1_category": "Age_yr_50_54_P",
#             "population": 0
#         },
#         {
#             "SED_CODE_2021": "SED10001",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5414
#         },
#         {
#             "SED_CODE_2021": "SED10002",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 6019
#         },
#         {
#             "SED_CODE_2021": "SED10003",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5630
#         },
#         {
#             "SED_CODE_2021": "SED10004",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4909
#         },
#         {
#             "SED_CODE_2021": "SED10005",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5365
#         },
#         {
#             "SED_CODE_2021": "SED10006",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5231
#         },
#         {
#             "SED_CODE_2021": "SED10007",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5438
#         },
#         {
#             "SED_CODE_2021": "SED10008",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5426
#         },
#         {
#             "SED_CODE_2021": "SED10009",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5935
#         },
#         {
#             "SED_CODE_2021": "SED10010",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5011
#         },
#         {
#             "SED_CODE_2021": "SED10011",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4970
#         },
#         {
#             "SED_CODE_2021": "SED10012",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5873
#         },
#         {
#             "SED_CODE_2021": "SED10013",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 6184
#         },
#         {
#             "SED_CODE_2021": "SED10014",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4742
#         },
#         {
#             "SED_CODE_2021": "SED10015",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5949
#         },
#         {
#             "SED_CODE_2021": "SED10016",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5727
#         },
#         {
#             "SED_CODE_2021": "SED10017",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4985
#         },
#         {
#             "SED_CODE_2021": "SED10018",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4505
#         },
#         {
#             "SED_CODE_2021": "SED10019",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5594
#         },
#         {
#             "SED_CODE_2021": "SED10020",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5064
#         },
#         {
#             "SED_CODE_2021": "SED10021",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4349
#         },
#         {
#             "SED_CODE_2021": "SED10022",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4995
#         },
#         {
#             "SED_CODE_2021": "SED10023",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5102
#         },
#         {
#             "SED_CODE_2021": "SED10024",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5413
#         },
#         {
#             "SED_CODE_2021": "SED10025",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5156
#         },
#         {
#             "SED_CODE_2021": "SED10026",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4986
#         },
#         {
#             "SED_CODE_2021": "SED10027",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5069
#         },
#         {
#             "SED_CODE_2021": "SED10028",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5645
#         },
#         {
#             "SED_CODE_2021": "SED10029",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 6081
#         },
#         {
#             "SED_CODE_2021": "SED10030",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5338
#         },
#         {
#             "SED_CODE_2021": "SED10031",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5950
#         },
#         {
#             "SED_CODE_2021": "SED10032",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5028
#         },
#         {
#             "SED_CODE_2021": "SED10033",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5291
#         },
#         {
#             "SED_CODE_2021": "SED10034",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4954
#         },
#         {
#             "SED_CODE_2021": "SED10035",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4687
#         },
#         {
#             "SED_CODE_2021": "SED10036",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5381
#         },
#         {
#             "SED_CODE_2021": "SED10037",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5516
#         },
#         {
#             "SED_CODE_2021": "SED10038",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5080
#         },
#         {
#             "SED_CODE_2021": "SED10039",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5216
#         },
#         {
#             "SED_CODE_2021": "SED10040",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5528
#         },
#         {
#             "SED_CODE_2021": "SED10041",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5326
#         },
#         {
#             "SED_CODE_2021": "SED10042",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5131
#         },
#         {
#             "SED_CODE_2021": "SED10043",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5248
#         },
#         {
#             "SED_CODE_2021": "SED10044",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5120
#         },
#         {
#             "SED_CODE_2021": "SED10045",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5844
#         },
#         {
#             "SED_CODE_2021": "SED10046",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 6059
#         },
#         {
#             "SED_CODE_2021": "SED10047",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5612
#         },
#         {
#             "SED_CODE_2021": "SED10048",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 6128
#         },
#         {
#             "SED_CODE_2021": "SED10049",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5035
#         },
#         {
#             "SED_CODE_2021": "SED10050",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5356
#         },
#         {
#             "SED_CODE_2021": "SED10051",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5381
#         },
#         {
#             "SED_CODE_2021": "SED10052",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4933
#         },
#         {
#             "SED_CODE_2021": "SED10053",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5897
#         },
#         {
#             "SED_CODE_2021": "SED10054",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5410
#         },
#         {
#             "SED_CODE_2021": "SED10055",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5484
#         },
#         {
#             "SED_CODE_2021": "SED10056",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5706
#         },
#         {
#             "SED_CODE_2021": "SED10057",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5284
#         },
#         {
#             "SED_CODE_2021": "SED10058",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4924
#         },
#         {
#             "SED_CODE_2021": "SED10059",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4068
#         },
#         {
#             "SED_CODE_2021": "SED10060",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4711
#         },
#         {
#             "SED_CODE_2021": "SED10061",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5375
#         },
#         {
#             "SED_CODE_2021": "SED10062",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5298
#         },
#         {
#             "SED_CODE_2021": "SED10063",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4993
#         },
#         {
#             "SED_CODE_2021": "SED10064",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5738
#         },
#         {
#             "SED_CODE_2021": "SED10065",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5702
#         },
#         {
#             "SED_CODE_2021": "SED10066",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4633
#         },
#         {
#             "SED_CODE_2021": "SED10067",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5432
#         },
#         {
#             "SED_CODE_2021": "SED10068",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5418
#         },
#         {
#             "SED_CODE_2021": "SED10069",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5406
#         },
#         {
#             "SED_CODE_2021": "SED10070",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5065
#         },
#         {
#             "SED_CODE_2021": "SED10071",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5376
#         },
#         {
#             "SED_CODE_2021": "SED10072",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5174
#         },
#         {
#             "SED_CODE_2021": "SED10073",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5627
#         },
#         {
#             "SED_CODE_2021": "SED10074",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4548
#         },
#         {
#             "SED_CODE_2021": "SED10075",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5544
#         },
#         {
#             "SED_CODE_2021": "SED10076",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5177
#         },
#         {
#             "SED_CODE_2021": "SED10077",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5452
#         },
#         {
#             "SED_CODE_2021": "SED10078",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4803
#         },
#         {
#             "SED_CODE_2021": "SED10079",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5095
#         },
#         {
#             "SED_CODE_2021": "SED10080",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4726
#         },
#         {
#             "SED_CODE_2021": "SED10081",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4919
#         },
#         {
#             "SED_CODE_2021": "SED10082",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5108
#         },
#         {
#             "SED_CODE_2021": "SED10083",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4925
#         },
#         {
#             "SED_CODE_2021": "SED10084",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5311
#         },
#         {
#             "SED_CODE_2021": "SED10085",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5560
#         },
#         {
#             "SED_CODE_2021": "SED10086",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4247
#         },
#         {
#             "SED_CODE_2021": "SED10087",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4743
#         },
#         {
#             "SED_CODE_2021": "SED10088",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5332
#         },
#         {
#             "SED_CODE_2021": "SED10089",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4755
#         },
#         {
#             "SED_CODE_2021": "SED10090",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5074
#         },
#         {
#             "SED_CODE_2021": "SED10091",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5058
#         },
#         {
#             "SED_CODE_2021": "SED10092",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 5308
#         },
#         {
#             "SED_CODE_2021": "SED10093",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 4997
#         },
#         {
#             "SED_CODE_2021": "SED19494",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 844
#         },
#         {
#             "SED_CODE_2021": "SED19797",
#             "l1_category": "Age_yr_55_59_P",
#             "population": 0
#         },
#         {
#             "SED_CODE_2021": "SED10001",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5812
#         },
#         {
#             "SED_CODE_2021": "SED10002",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5390
#         },
#         {
#             "SED_CODE_2021": "SED10003",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 6075
#         },
#         {
#             "SED_CODE_2021": "SED10004",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4149
#         },
#         {
#             "SED_CODE_2021": "SED10005",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4978
#         },
#         {
#             "SED_CODE_2021": "SED10006",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5489
#         },
#         {
#             "SED_CODE_2021": "SED10007",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5509
#         },
#         {
#             "SED_CODE_2021": "SED10008",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4993
#         },
#         {
#             "SED_CODE_2021": "SED10009",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 7337
#         },
#         {
#             "SED_CODE_2021": "SED10010",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4572
#         },
#         {
#             "SED_CODE_2021": "SED10011",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5370
#         },
#         {
#             "SED_CODE_2021": "SED10012",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5803
#         },
#         {
#             "SED_CODE_2021": "SED10013",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5358
#         },
#         {
#             "SED_CODE_2021": "SED10014",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4561
#         },
#         {
#             "SED_CODE_2021": "SED10015",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5078
#         },
#         {
#             "SED_CODE_2021": "SED10016",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5011
#         },
#         {
#             "SED_CODE_2021": "SED10017",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5178
#         },
#         {
#             "SED_CODE_2021": "SED10018",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4465
#         },
#         {
#             "SED_CODE_2021": "SED10019",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 6144
#         },
#         {
#             "SED_CODE_2021": "SED10020",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5518
#         },
#         {
#             "SED_CODE_2021": "SED10021",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 3698
#         },
#         {
#             "SED_CODE_2021": "SED10022",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5278
#         },
#         {
#             "SED_CODE_2021": "SED10023",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5043
#         },
#         {
#             "SED_CODE_2021": "SED10024",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4343
#         },
#         {
#             "SED_CODE_2021": "SED10025",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4519
#         },
#         {
#             "SED_CODE_2021": "SED10026",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5022
#         },
#         {
#             "SED_CODE_2021": "SED10027",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4897
#         },
#         {
#             "SED_CODE_2021": "SED10028",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5239
#         },
#         {
#             "SED_CODE_2021": "SED10029",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5692
#         },
#         {
#             "SED_CODE_2021": "SED10030",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5338
#         },
#         {
#             "SED_CODE_2021": "SED10031",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5777
#         },
#         {
#             "SED_CODE_2021": "SED10032",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4489
#         },
#         {
#             "SED_CODE_2021": "SED10033",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4795
#         },
#         {
#             "SED_CODE_2021": "SED10034",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4533
#         },
#         {
#             "SED_CODE_2021": "SED10035",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 3919
#         },
#         {
#             "SED_CODE_2021": "SED10036",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4592
#         },
#         {
#             "SED_CODE_2021": "SED10037",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4895
#         },
#         {
#             "SED_CODE_2021": "SED10038",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4936
#         },
#         {
#             "SED_CODE_2021": "SED10039",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5644
#         },
#         {
#             "SED_CODE_2021": "SED10040",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5108
#         },
#         {
#             "SED_CODE_2021": "SED10041",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4639
#         },
#         {
#             "SED_CODE_2021": "SED10042",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5508
#         },
#         {
#             "SED_CODE_2021": "SED10043",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4834
#         },
#         {
#             "SED_CODE_2021": "SED10044",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4528
#         },
#         {
#             "SED_CODE_2021": "SED10045",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 6457
#         },
#         {
#             "SED_CODE_2021": "SED10046",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5270
#         },
#         {
#             "SED_CODE_2021": "SED10047",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5027
#         },
#         {
#             "SED_CODE_2021": "SED10048",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5621
#         },
#         {
#             "SED_CODE_2021": "SED10049",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4906
#         },
#         {
#             "SED_CODE_2021": "SED10050",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4337
#         },
#         {
#             "SED_CODE_2021": "SED10051",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4552
#         },
#         {
#             "SED_CODE_2021": "SED10052",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4674
#         },
#         {
#             "SED_CODE_2021": "SED10053",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5310
#         },
#         {
#             "SED_CODE_2021": "SED10054",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4859
#         },
#         {
#             "SED_CODE_2021": "SED10055",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5182
#         },
#         {
#             "SED_CODE_2021": "SED10056",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 6095
#         },
#         {
#             "SED_CODE_2021": "SED10057",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 6439
#         },
#         {
#             "SED_CODE_2021": "SED10058",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 5012
#         },
#         {
#             "SED_CODE_2021": "SED10059",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 3339
#         },
#         {
#             "SED_CODE_2021": "SED10060",
#             "l1_category": "Age_yr_60_64_P",
#             "population": 4451
# ...
#             "population": 225
#         },
#         {
#             "SED_CODE_2021": "SED10078",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 185
#         },
#         {
#             "SED_CODE_2021": "SED10079",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 116
#         },
#         {
#             "SED_CODE_2021": "SED10080",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 120
#         },
#         {
#             "SED_CODE_2021": "SED10081",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 151
#         },
#         {
#             "SED_CODE_2021": "SED10082",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 191
#         },
#         {
#             "SED_CODE_2021": "SED10083",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 213
#         },
#         {
#             "SED_CODE_2021": "SED10084",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 286
#         },
#         {
#             "SED_CODE_2021": "SED10085",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 110
#         },
#         {
#             "SED_CODE_2021": "SED10086",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 228
#         },
#         {
#             "SED_CODE_2021": "SED10087",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 157
#         },
#         {
#             "SED_CODE_2021": "SED10088",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 191
#         },
#         {
#             "SED_CODE_2021": "SED10089",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 240
#         },
#         {
#             "SED_CODE_2021": "SED10090",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 247
#         },
#         {
#             "SED_CODE_2021": "SED10091",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 175
#         },
#         {
#             "SED_CODE_2021": "SED10092",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 182
#         },
#         {
#             "SED_CODE_2021": "SED10093",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 178
#         },
#         {
#             "SED_CODE_2021": "SED19494",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 3
#         },
#         {
#             "SED_CODE_2021": "SED19797",
#             "l1_category": "Age_yr_95_99_P",
#             "population": 0
#         },
#         {
#             "SED_CODE_2021": "SED10001",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10002",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 13
#         },
#         {
#             "SED_CODE_2021": "SED10003",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 24
#         },
#         {
#             "SED_CODE_2021": "SED10004",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 6
#         },
#         {
#             "SED_CODE_2021": "SED10005",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 28
#         },
#         {
#             "SED_CODE_2021": "SED10006",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 13
#         },
#         {
#             "SED_CODE_2021": "SED10007",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 13
#         },
#         {
#             "SED_CODE_2021": "SED10008",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 15
#         },
#         {
#             "SED_CODE_2021": "SED10009",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 21
#         },
#         {
#             "SED_CODE_2021": "SED10010",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10011",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 15
#         },
#         {
#             "SED_CODE_2021": "SED10012",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 23
#         },
#         {
#             "SED_CODE_2021": "SED10013",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 17
#         },
#         {
#             "SED_CODE_2021": "SED10014",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 5
#         },
#         {
#             "SED_CODE_2021": "SED10015",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10016",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 14
#         },
#         {
#             "SED_CODE_2021": "SED10017",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 10
#         },
#         {
#             "SED_CODE_2021": "SED10018",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 27
#         },
#         {
#             "SED_CODE_2021": "SED10019",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 15
#         },
#         {
#             "SED_CODE_2021": "SED10020",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 26
#         },
#         {
#             "SED_CODE_2021": "SED10021",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 46
#         },
#         {
#             "SED_CODE_2021": "SED10022",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10023",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 24
#         },
#         {
#             "SED_CODE_2021": "SED10024",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10025",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 26
#         },
#         {
#             "SED_CODE_2021": "SED10026",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 12
#         },
#         {
#             "SED_CODE_2021": "SED10027",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 28
#         },
#         {
#             "SED_CODE_2021": "SED10028",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 47
#         },
#         {
#             "SED_CODE_2021": "SED10029",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 17
#         },
#         {
#             "SED_CODE_2021": "SED10030",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 31
#         },
#         {
#             "SED_CODE_2021": "SED10031",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 11
#         },
#         {
#             "SED_CODE_2021": "SED10032",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 10
#         },
#         {
#             "SED_CODE_2021": "SED10033",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 15
#         },
#         {
#             "SED_CODE_2021": "SED10034",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 26
#         },
#         {
#             "SED_CODE_2021": "SED10035",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 5
#         },
#         {
#             "SED_CODE_2021": "SED10036",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10037",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 13
#         },
#         {
#             "SED_CODE_2021": "SED10038",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10039",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 14
#         },
#         {
#             "SED_CODE_2021": "SED10040",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 17
#         },
#         {
#             "SED_CODE_2021": "SED10041",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 37
#         },
#         {
#             "SED_CODE_2021": "SED10042",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 39
#         },
#         {
#             "SED_CODE_2021": "SED10043",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 12
#         },
#         {
#             "SED_CODE_2021": "SED10044",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 34
#         },
#         {
#             "SED_CODE_2021": "SED10045",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 19
#         },
#         {
#             "SED_CODE_2021": "SED10046",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 7
#         },
#         {
#             "SED_CODE_2021": "SED10047",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 7
#         },
#         {
#             "SED_CODE_2021": "SED10048",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 13
#         },
#         {
#             "SED_CODE_2021": "SED10049",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 9
#         },
#         {
#             "SED_CODE_2021": "SED10050",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10051",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 25
#         },
#         {
#             "SED_CODE_2021": "SED10052",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 43
#         },
#         {
#             "SED_CODE_2021": "SED10053",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 10
#         },
#         {
#             "SED_CODE_2021": "SED10054",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 17
#         },
#         {
#             "SED_CODE_2021": "SED10055",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 6
#         },
#         {
#             "SED_CODE_2021": "SED10056",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 25
#         },
#         {
#             "SED_CODE_2021": "SED10057",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 28
#         },
#         {
#             "SED_CODE_2021": "SED10058",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10059",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 5
#         },
#         {
#             "SED_CODE_2021": "SED10060",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 19
#         },
#         {
#             "SED_CODE_2021": "SED10061",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 19
#         },
#         {
#             "SED_CODE_2021": "SED10062",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 42
#         },
#         {
#             "SED_CODE_2021": "SED10063",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 23
#         },
#         {
#             "SED_CODE_2021": "SED10064",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 17
#         },
#         {
#             "SED_CODE_2021": "SED10065",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10066",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10067",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 59
#         },
#         {
#             "SED_CODE_2021": "SED10068",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 35
#         },
#         {
#             "SED_CODE_2021": "SED10069",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 22
#         },
#         {
#             "SED_CODE_2021": "SED10070",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 10
#         },
#         {
#             "SED_CODE_2021": "SED10071",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 5
#         },
#         {
#             "SED_CODE_2021": "SED10072",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 7
#         },
#         {
#             "SED_CODE_2021": "SED10073",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 27
#         },
#         {
#             "SED_CODE_2021": "SED10074",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10075",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 8
#         },
#         {
#             "SED_CODE_2021": "SED10076",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 25
#         },
#         {
#             "SED_CODE_2021": "SED10077",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 18
#         },
#         {
#             "SED_CODE_2021": "SED10078",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 37
#         },
#         {
#             "SED_CODE_2021": "SED10079",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 10
#         },
#         {
#             "SED_CODE_2021": "SED10080",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 15
#         },
#         {
#             "SED_CODE_2021": "SED10081",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 20
#         },
#         {
#             "SED_CODE_2021": "SED10082",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 32
#         },
#         {
#             "SED_CODE_2021": "SED10083",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 26
#         },
#         {
#             "SED_CODE_2021": "SED10084",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 42
#         },
#         {
#             "SED_CODE_2021": "SED10085",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 19
#         },
#         {
#             "SED_CODE_2021": "SED10086",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 22
#         },
#         {
#             "SED_CODE_2021": "SED10087",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 21
#         },
#         {
#             "SED_CODE_2021": "SED10088",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 22
#         },
#         {
#             "SED_CODE_2021": "SED10089",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 32
#         },
#         {
#             "SED_CODE_2021": "SED10090",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 33
#         },
#         {
#             "SED_CODE_2021": "SED10091",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 29
#         },
#         {
#             "SED_CODE_2021": "SED10092",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 16
#         },
#         {
#             "SED_CODE_2021": "SED10093",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 29
#         },
#         {
#             "SED_CODE_2021": "SED19494",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 0
#         },
#         {
#             "SED_CODE_2021": "SED19797",
#             "l1_category": "Age_yr_100_yr_over_P",
#             "population": 0
#         }
#     ]
# }

# %%
for idx, row in g04.melt().iterrows():
    if idx <100:
        print(f"{row[1]} - {row[2]}: {row[3]}")
# Out:
# SED10001 - Age_yr_45_49_P: 4932
# SED10002 - Age_yr_45_49_P: 6328
# SED10003 - Age_yr_45_49_P: 5582
# SED10004 - Age_yr_45_49_P: 6296
# SED10005 - Age_yr_45_49_P: 5667
# SED10006 - Age_yr_45_49_P: 4124
# SED10007 - Age_yr_45_49_P: 4914
# SED10008 - Age_yr_45_49_P: 6293
# SED10009 - Age_yr_45_49_P: 4205
# SED10010 - Age_yr_45_49_P: 5517
# SED10011 - Age_yr_45_49_P: 5012
# SED10012 - Age_yr_45_49_P: 5450
# SED10013 - Age_yr_45_49_P: 8613
# SED10014 - Age_yr_45_49_P: 5031
# SED10015 - Age_yr_45_49_P: 6468
# SED10016 - Age_yr_45_49_P: 8026
# SED10017 - Age_yr_45_49_P: 5362
# SED10018 - Age_yr_45_49_P: 5003
# SED10019 - Age_yr_45_49_P: 4529
# SED10020 - Age_yr_45_49_P: 4889
# SED10021 - Age_yr_45_49_P: 5597
# SED10022 - Age_yr_45_49_P: 4206
# SED10023 - Age_yr_45_49_P: 5681
# SED10024 - Age_yr_45_49_P: 6443
# SED10025 - Age_yr_45_49_P: 5673
# SED10026 - Age_yr_45_49_P: 4675
# SED10027 - Age_yr_45_49_P: 5457
# SED10028 - Age_yr_45_49_P: 6146
# SED10029 - Age_yr_45_49_P: 5898
# SED10030 - Age_yr_45_49_P: 5030
# SED10031 - Age_yr_45_49_P: 5310
# SED10032 - Age_yr_45_49_P: 5810
# SED10033 - Age_yr_45_49_P: 5348
# SED10034 - Age_yr_45_49_P: 5599
# SED10035 - Age_yr_45_49_P: 6300
# SED10036 - Age_yr_45_49_P: 6167
# SED10037 - Age_yr_45_49_P: 6537
# SED10038 - Age_yr_45_49_P: 5677
# SED10039 - Age_yr_45_49_P: 4684
# SED10040 - Age_yr_45_49_P: 5469
# SED10041 - Age_yr_45_49_P: 6379
# SED10042 - Age_yr_45_49_P: 4783
# SED10043 - Age_yr_45_49_P: 5338
# SED10044 - Age_yr_45_49_P: 6270
# SED10045 - Age_yr_45_49_P: 4913
# SED10046 - Age_yr_45_49_P: 6167
# SED10047 - Age_yr_45_49_P: 7163
# SED10048 - Age_yr_45_49_P: 6926
# SED10049 - Age_yr_45_49_P: 5539
# SED10050 - Age_yr_45_49_P: 6617
# SED10051 - Age_yr_45_49_P: 6282
# SED10052 - Age_yr_45_49_P: 5683
# SED10053 - Age_yr_45_49_P: 5911
# SED10054 - Age_yr_45_49_P: 5935
# SED10055 - Age_yr_45_49_P: 6031
# SED10056 - Age_yr_45_49_P: 5101
# SED10057 - Age_yr_45_49_P: 4043
# SED10058 - Age_yr_45_49_P: 4924
# SED10059 - Age_yr_45_49_P: 5212
# SED10060 - Age_yr_45_49_P: 5297
# SED10061 - Age_yr_45_49_P: 4542
# SED10062 - Age_yr_45_49_P: 5372
# SED10063 - Age_yr_45_49_P: 4862
# SED10064 - Age_yr_45_49_P: 4398
# SED10065 - Age_yr_45_49_P: 6520
# SED10066 - Age_yr_45_49_P: 5390
# SED10067 - Age_yr_45_49_P: 5480
# SED10068 - Age_yr_45_49_P: 4686
# SED10069 - Age_yr_45_49_P: 4635
# SED10070 - Age_yr_45_49_P: 5594
# SED10071 - Age_yr_45_49_P: 8710
# SED10072 - Age_yr_45_49_P: 5751
# SED10073 - Age_yr_45_49_P: 5882
# SED10074 - Age_yr_45_49_P: 5658
# SED10075 - Age_yr_45_49_P: 5735
# SED10076 - Age_yr_45_49_P: 4139
# SED10077 - Age_yr_45_49_P: 5673
# SED10078 - Age_yr_45_49_P: 5600
# SED10079 - Age_yr_45_49_P: 4441
# SED10080 - Age_yr_45_49_P: 5679
# SED10081 - Age_yr_45_49_P: 4663
# SED10082 - Age_yr_45_49_P: 5135
# SED10083 - Age_yr_45_49_P: 4809
# SED10084 - Age_yr_45_49_P: 5105
# SED10085 - Age_yr_45_49_P: 5044
# SED10086 - Age_yr_45_49_P: 5394
# SED10087 - Age_yr_45_49_P: 4639
# SED10088 - Age_yr_45_49_P: 6495
# SED10089 - Age_yr_45_49_P: 5228
# SED10090 - Age_yr_45_49_P: 6686
# SED10091 - Age_yr_45_49_P: 5474
# SED10092 - Age_yr_45_49_P: 4958
# SED10093 - Age_yr_45_49_P: 5190
# SED19494 - Age_yr_45_49_P: 877
# SED19797 - Age_yr_45_49_P: 0
# SED10001 - Age_yr_50_54_P: 5262
# SED10002 - Age_yr_50_54_P: 6220
# SED10003 - Age_yr_50_54_P: 5517
# SED10004 - Age_yr_50_54_P: 5651
# SED10005 - Age_yr_50_54_P: 5323
# /var/folders/h4/40rl009s0kb57zjm1tj9msth0000gn/T/ipykernel_7253/2052859515.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"{row[1]} - {row[2]}: {row[3]}")

# %%
g07_level1 = ['Tot_Indigenous_P', 'Tot_Non_Indigenous_P']
g07_aggregates = ['Tot_Tot_P']
g07 = Table(code='g07',
            name='Indigenous status by age by sex',
            path='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G07_NSW_SED.csv', 
            level1=g07_level1, 
            aggregates=g07_aggregates)

print(g07)
# Out:
# Table name: Indigenous status by age by sex
# Table code: g07
# Dataset path: ../data/2021 Census GCP State Electroral Division for NSW/2021Census_G07_NSW_SED.csv
# Level 1 statistics: ['Tot_Indigenous_P', 'Tot_Non_Indigenous_P']
# Aggregate columns: ['Tot_Tot_P']

# %%
g14_level1 = ['Buddhism_P', 'Christianity_Tot_M', 'Hinduism_M', 'Islam_M', 'Judaism_M']
g14_aggregates = ['Tot_P']
g14 = Table(code='g14',
            name='Religious affiliation by sex',
            path='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G14_NSW_SED.csv', 
            level1=g14_level1, 
            aggregates=g14_aggregates)

g14.summary_stats()
# Out:
#    SED_CODE_2021  Buddhism_M  Buddhism_F  Buddhism_P  Christianity_Anglican_M  \
# 0       SED10001         213         347         559                     5278
# 1       SED10002        3184        4095        7277                     1362
# 2       SED10003         485         757        1247                     4292
# 3       SED10004         910        1467        2375                     2733
# 4       SED10005        3948        4749        8697                     1262
# ..           ...         ...         ...         ...                      ...
# 90      SED10091         247         365         612                     7839
# 91      SED10092         495         706        1204                     4006
# 92      SED10093         270         435         704                     6451
# 93      SED19494          61          71         134                      488
# 94      SED19797           0           0           0                        0
#
#     Christianity_Anglican_F  Christianity_Anglican_P  \
# 0                      6398                    11673
# 1                      1441                     2800
# 2                      5097                     9389
# 3                      3313                     6050
# 4                      1425                     2689
# ..                      ...                      ...
# 90                     9256                    17097
# 91                     4897                     8901
# 92                     7886                    14331
# 93                      411                      898
# 94                        0                        0
#
#     Christianity_Asyrin_Apstlic_M  Christianity_Asyrin_Apstlic_F  \
# 0                               0                              0
# 1                              10                              9
# 2                               0                              0
# 3                               4                              3
# 4                              25                             25
# ..                            ...                            ...
# 90                              3                              6
# 91                              3                              6
# 92                              3                              0
# 93                              0                              0
# 94                              0                              0
#
#     Christianity_Asyrin_Apstlic_P  ...  Religious_affiliation_ns_F  \
# 0                               0  ...                        3112
# 1                              17  ...                        4614
# 2                               0  ...                        3972
# 3                              13  ...                        2719
# 4                              48  ...                        4547
# ..                            ...  ...                         ...
# 90                             13  ...                        2486
# 91                             13  ...                        2774
# 92                              3  ...                        2985
# 93                              0  ...                        1655
# 94                              0  ...                           0
#
#     Religious_affiliation_ns_P  Tot_M  Tot_F   Tot_P  Buddhism_P_by_Tot_P  \
# 0                         6723  41715  43275   84989             0.657732
# 1                        11029  61755  56069  117822             6.176266
# 2                         7933  39585  42816   82405             1.513258
# 3                         5612  40216  43054   83273             2.852065
# 4                         9592  47284  47384   94669             9.186745
# ..                         ...    ...    ...     ...                  ...
# 90                        5009  40907  42254   83158             0.735948
# 91                        5765  42327  42976   85299             1.411505
# 92                        5964  40098  42439   82534             0.852982
# 93                        4113   6375   4997   11371             1.178436
# 94                           0      0      0       0                  NaN
#
#     Christianity_Tot_M_by_Tot_P  Hinduism_M_by_Tot_P  Islam_M_by_Tot_P  \
# 0                     23.513631             0.837755          0.258857
# 1                     12.899968             4.418530         13.231824
# 2                     16.875190             0.183241          0.081306
# 3                     15.547657             0.596832          0.560806
# 4                     16.104533             0.531325         16.131997
# ..                          ...                  ...               ...
# 90                    27.114649             0.383607          0.353544
# 91                    23.530170             0.703408          2.324763
# 92                    23.370974             0.361063          0.253229
# 93                    14.299534             0.360566          0.861842
# 94                          NaN                  NaN               NaN
#
#     Judaism_M_by_Tot_P
# 0             0.024709
# 1             0.010185
# 2             0.311874
# 3             0.285807
# 4             0.008450
# ..                 ...
# 90            0.084177
# 91            0.035170
# 92            0.025444
# 93            0.087943
# 94                 NaN
#
# [95 rows x 108 columns]

# %%
g18_level1 = ['P_Tot_Need_for_assistance', 'P_Tot_No_need_for_assistance']
g18_aggregates = ['P_Tot_Tot']
g18 = Table(code='g18',
            name='Core activity need for assistance by age by sex',
            path='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G18_NSW_SED.csv', 
            level1=g18_level1, 
            aggregates=g18_aggregates)

g18.summary_stats()
# Out:
#    SED_CODE_2021  M_0_4_yrs_Need_for_assistance  M_0_4_No_need_for_assistance  \
# 0       SED10001                             54                          2355
# 1       SED10002                             60                          3572
# 2       SED10003                             30                          1839
# 3       SED10004                             26                          2141
# 4       SED10005                             63                          3186
# ..           ...                            ...                           ...
# 90      SED10091                             70                          2525
# 91      SED10092                             52                          2098
# 92      SED10093                             73                          2410
# 93      SED19494                              6                           157
# 94      SED19797                              0                             0
#
#     M_0_4_Need_for_assistance_ns  M_0_4_yrs_Tot  M_5_14_Need_for_assistance  \
# 0                            185           2603                         400
# 1                            340           3969                         190
# 2                            155           2024                         237
# 3                             86           2252                         126
# 4                            357           3604                         310
# ..                           ...            ...                         ...
# 90                           105           2703                         335
# 91                           127           2282                         252
# 92                           158           2630                         590
# 93                            87            258                          24
# 94                             0              0                           0
#
#     M_5_14_No_need_for_assistance  M_5_14_Need_for_assistance_ns  \
# 0                            4641                            414
# 1                            5591                            516
# 2                            4209                            399
# 3                            3790                            166
# 4                            5813                            724
# ..                            ...                            ...
# 90                           5202                            267
# 91                           3802                            265
# 92                           4711                            325
# 93                            200                            167
# 94                              0                              0
#
#     M_5_14_yrs_Tot  M_15_19_Need_for_assistance  ...  \
# 0             5453                          140  ...
# 1             6304                           68  ...
# 2             4845                          101  ...
# 3             4085                           37  ...
# 4             6844                          102  ...
# ..             ...                          ...  ...
# 90            5805                          123  ...
# 91            4320                           99  ...
# 92            5624                          188  ...
# 93             382                            8  ...
# 94               0                            0  ...
#
#     P_85_over_Need_for_assistance  P_85_ov_No_need_for_assistnce  \
# 0                            1053                            980
# 1                             743                            376
# 2                            1080                           1082
# 3                             582                            401
# 4                            1022                            567
# ..                            ...                            ...
# 90                            761                            888
# 91                           1297                            884
# 92                           1035                            827
# 93                             15                             14
# 94                              0                              0
#
#     P_85_ov_Need_for_assistnce_ns  P_85_yrs_over_Tot  \
# 0                             173               2205
# 1                             161               1282
# 2                             256               2422
# 3                              98               1075
# 4                             335               1919
# ..                            ...                ...
# 90                            351               2002
# 91                            317               2497
# 92                            388               2249
# 93                             14                 49
# 94                              0                  0
#
#     P_Tot_Need_for_assistance  P_Tot_No_need_for_assistance  \
# 0                        5751                         73574
# 1                        5748                        102114
# 2                        4606                         71470
# 3                        3054                         75975
# 4                        6680                         79282
# ..                        ...                           ...
# 90                       4376                         74708
# 91                       6502                         74074
# 92                       6832                         70756
# 93                        537                          7010
# 94                          0                             0
#
#     P_Tot_Need_for_assistance_ns  P_Tot_Tot  \
# 0                           5668      84989
# 1                           9959     117822
# 2                           6335      82405
# 3                           4241      83273
# 4                           8707      94669
# ..                           ...        ...
# 90                          4079      83158
# 91                          4722      85299
# 92                          4947      82534
# 93                          3831      11371
# 94                             0          0
#
#     P_Tot_Need_for_assistance_by_P_Tot_Tot  \
# 0                                 6.766758
# 1                                 4.878546
# 2                                 5.589467
# 3                                 3.667455
# 4                                 7.056164
# ..                                     ...
# 90                                5.262272
# 91                                7.622598
# 92                                8.277801
# 93                                4.722540
# 94                                     NaN
#
#     P_Tot_No_need_for_assistance_by_P_Tot_Tot
# 0                                   86.568850
# 1                                   86.668025
# 2                                   86.730174
# 3                                   91.236055
# 4                                   83.746527
# ..                                        ...
# 90                                  89.838620
# 91                                  86.840408
# 92                                  85.729518
# 93                                  61.648052
# 94                                        NaN
#
# [95 rows x 147 columns]

# %%
g33_level1 = ['Negative_Nil_income_Tot', 'HI_1_149_Tot', 'HI_150_299_Tot', 'HI_300_399_Tot', 'HI_400_499_Tot', 'HI_500_649_Tot', 'HI_650_799_Tot', 'HI_800_999_Tot',
              'HI_1000_1249_Tot', 'HI_1250_1499_Tot', 'HI_1500_1749_Tot', 'HI_1750_1999_Tot', 'HI_2000_2499_Tot', 'HI_2500_2999_Tot', 'HI_3000_3499_Tot', 'HI_3500_3999_Tot',
              'HI_4000_more_Tot']
g33_aggregates = ['Tot_Tot']
g33 = Table(code='g33',
            name='Total household income (weekly) by household composition',
            path='../data/2021 Census GCP State Electroral Division for NSW/2021Census_G33_NSW_SED.csv', 
            level1=g33_level1, 
            aggregates=g33_aggregates)

g33.summary_stats()
# Out:
#    SED_CODE_2021  Neg_Nil_inc_fam_households  Neg_Nil_inc_Non_fam_househlds  \
# 0       SED10001                         200                            314
# 1       SED10002                         580                            610
# 2       SED10003                         173                            291
# 3       SED10004                         186                            557
# 4       SED10005                         463                            390
# ..           ...                         ...                            ...
# 90      SED10091                         221                            249
# 91      SED10092                         259                            405
# 92      SED10093                         217                            308
# 93      SED19494                           0                              0
# 94      SED19797                           0                              0
#
#     Negative_Nil_income_Tot  HI_1_149_Family_households  \
# 0                       511                          95
# 1                      1186                         113
# 2                       463                          91
# 3                       742                          80
# 4                       853                         116
# ..                      ...                         ...
# 90                      467                          92
# 91                      666                          79
# 92                      524                          72
# 93                        0                           0
# 94                        0                           0
#
#     HI_1_149_Non_family_hseholds  HI_1_149_Tot  HI_150_299_Family_households  \
# 0                            127           224                           109
# 1                            114           232                           185
# 2                            144           232                            75
# 3                            143           224                            67
# 4                             76           195                           181
# ..                           ...           ...                           ...
# 90                            99           186                            66
# 91                           171           251                           108
# 92                            96           164                            68
# 93                             0             0                             0
# 94                             0             0                             0
#
#     HI_150_299_Non_fam_househlds  HI_150_299_Tot  ...  \
# 0                            396             505  ...
# 1                            319             505  ...
# 2                            274             355  ...
# 3                            379             445  ...
# 4                            383             562  ...
# ..                           ...             ...  ...
# 90                           183             251  ...
# 91                           490             595  ...
# 92                           245             309  ...
# 93                             0               0  ...
# 94                             0               0  ...
#
#     HI_800_999_Tot_by_Tot_Tot  HI_1000_1249_Tot_by_Tot_Tot  \
# 0                    7.082529                     7.972370
# 1                    5.498209                     7.403476
# 2                    6.955991                     7.601194
# 3                    3.717706                     4.846194
# 4                    6.866800                     7.954221
# ..                        ...                          ...
# 90                   5.392413                     6.514091
# 91                   6.626259                     7.290935
# 92                   7.005107                     7.539309
# 93                        NaN                          NaN
# 94                        NaN                          NaN
#
#     HI_1250_1499_Tot_by_Tot_Tot  HI_1500_1749_Tot_by_Tot_Tot  \
# 0                      7.809484                     5.851834
# 1                      7.703330                     6.384503
# 2                      7.684653                     5.543607
# 3                      4.808959                     4.399381
# 4                      7.964917                     5.979036
# ..                          ...                          ...
# 90                     6.872888                     4.998781
# 91                     7.337784                     5.416959
# 92                     7.498992                     5.714958
# 93                          NaN                          NaN
# 94                          NaN                          NaN
#
#     HI_1750_1999_Tot_by_Tot_Tot  HI_2000_2499_Tot_by_Tot_Tot  \
# 0                      5.526062                    10.853041
# 1                      5.997081                    12.500995
# 2                      5.508298                    10.512631
# 3                      4.402246                    10.316778
# 4                      5.561894                     9.990017
# ..                          ...                          ...
# 90                     5.409830                    11.248128
# 91                     5.419888                    10.511829
# 92                     5.657842                    10.855396
# 93                          NaN                          NaN
# 94                          NaN                          NaN
#
#     HI_2500_2999_Tot_by_Tot_Tot  HI_3000_3499_Tot_by_Tot_Tot  \
# 0                      6.587838                     5.073600
# 1                      7.305294                     6.068728
# 2                      6.615735                     5.190511
# 3                      4.934983                     6.510282
# 4                      6.438962                     4.649173
# ..                          ...                          ...
# 90                     8.220991                     7.590483
# 91                     6.614547                     5.498946
# 92                     7.559468                     5.620884
# 93                          NaN                          NaN
# 94                          NaN                          NaN
#
#     HI_3500_3999_Tot_by_Tot_Tot  HI_4000_more_Tot_by_Tot_Tot
# 0                      2.856540                     6.032819
# 1                      3.935253                    10.412631
# 2                      3.049466                     9.408404
# 3                      4.104371                    30.984705
# 4                      3.019823                     6.952367
# ..                          ...                          ...
# 90                     4.497161                    14.153342
# 91                     3.396580                     8.652495
# 92                     3.302647                     7.025265
# 93                          NaN                          NaN
# 94                          NaN                          NaN
#
# [95 rows x 78 columns]

# %%
all_tables = [g04, g07, g14, g18, g33]

# %%
def query_first_match(tables, attribute, value):    
    for table in tables:
        if getattr(table, attribute, None) == value:
            return table

# Example use
print(query(all_tables, "code", 'g04').get_name())
# Out:
# Age by sex

# %%
# Correlate with the rest
table1 = g33
correlations = {}

for table2 in all_tables:
    if table2.code != table1.code:
        c = table1.correlation(table2)
        correlations[table2.code] = c

print(f"{table1.name} (table code: {table1.code}) has the following correlations\n")
for k in correlations.keys():
    print(f"{k}: {correlations[k]:.2f} {query(all_tables, 'code', k).get_name()}")
# Out:
# Total household income (weekly) by household composition (table code: g33) has the following correlations
#
# g04: 0.41 Age by sex
# g07: 0.52 Indigenous status by age by sex
# g14: 0.42 Religious affiliation by sex
# g18: 0.54 Core activity need for assistance by age by sex

# %%
# Correlate with the rest
table1 = g18
correlations = {}

for table2 in all_tables:
    if table2.code != table1.code:
        c = table1.correlation(table2)
        correlations[table2.code] = c

print(f"{table1.name} (table code: {table1.code}) has the following correlations\n")
for k in correlations.keys():
    print(f"{k}: {correlations[k]:.2f} {query(all_tables, 'code', k).get_name()}")
# Out:
# Core activity need for assistance by age by sex (table code: g18) has the following correlations
#
# g04: 0.44 Age by sex
# g07: 0.55 Indigenous status by age by sex
# g14: 0.37 Religious affiliation by sex
# g33: 0.54 Total household income (weekly) by household composition

# %%
# Correlate with the rest
table1 = g04
correlations = {}

for table2 in all_tables:
    if table2.code != table1.code:
        c = table1.correlation(table2)
        correlations[table2.code] = c

print(f"{table1.name} (table code: {table1.code}) has the following correlations\n")
for k in correlations.keys():
    print(f"{k}: {correlations[k]:.2f} {query(all_tables, 'code', k).get_name()}")
# Out:
# Age by sex (table code: g04) has the following correlations
#
# g07: 0.43 Indigenous status by age by sex
# g14: 0.39 Religious affiliation by sex
# g18: 0.44 Core activity need for assistance by age by sex
# g33: 0.41 Total household income (weekly) by household composition
